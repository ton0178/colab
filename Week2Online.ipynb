# %% [markdown]
# <a href="https://colab.research.google.com/github/ton0178/colab/blob/main/Week2Online.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([1,2,2,np.nan],index = ['p','q','r','s'])
series
# Out:
# p    1.0
# q    2.0
# r    2.0
# s    NaN
# dtype: float64

# %%
# page 15
data = [1, 3, 5, 7, 9]
row_index = ['a', 'b', 'c', 'd', 'e']
series = pd.Series(data,index = row_index)

print(series)
# Out:
# a    1
# b    3
# c    5
# d    7
# e    9
# dtype: int64

# %%
series['a']
# Out:
# 1

# %%
# Page 17
datas = ('a','b','c','d','e')
ps = pd.Series(datas ,index = ['1','2','3','4','5'])
ps
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# 5    e
# dtype: object

# %%
for i in ps:
    print(i)
# Out:
# a
# b
# c
# d
# e

# %%
# Create a NumPy array
np_array = np.array([1, 2, 3, 4, 5])
# Convert the NumPy array to a Pandas Series
series = pd.Series(np_array)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
datas = [15, 12.5, "Oak", 22, "PIM"]
ndata = np.array(datas)
ps = pd.Series(ndata)
ps
# Out:
# 0      15
# 1    12.5
# 2     Oak
# 3      22
# 4     PIM
# dtype: object

# %%
# Creating a dictionary
data_dict = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# Converting the dictionary to a Pandas Series
series = pd.Series(data_dict)
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
# Page 21   Dictionary ของ List
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Boston', 'San Francisco']
}
df = pd.DataFrame(data)
#print(df)
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30         Boston
# 2  Charlie   35  San Francisco

# %%
# Page 21   List ของ Dictionary
data = [{'ID': 1, 'Name': 'Alice', 'Age': 28},
        {'ID': 2, 'Name': 'Bob', 'Age': 34},
        {'ID': 3, 'Name': 'Charlie', 'Age': 22}]

df = pd.DataFrame(data)
df
# Out:
#    ID     Name  Age
# 0   1    Alice   28
# 1   2      Bob   34
# 2   3  Charlie   22

# %%
# Example list
data_list = ['Apple', 10, 'Fruit'] # สร้าง Data เป็นแบบแถว
# Converting the list to a row in a DataFrame
df = pd.DataFrame([data_list], columns=['Item', 'Quantity', 'Category'])
df
# Out:
#     Item  Quantity Category
# 0  Apple        10    Fruit

# %%
new_data = ['มะละกอ',20,'Fruit']
df.loc[len(df)] = new_data

# %%
df
# Out:
#      Item  Quantity Category
# 0   Apple        10    Fruit
# 1  มะละกอ        20    Fruit

# %%
data = [[1, 'Alice', 28],
        [2, 'Bob', 34],
        [3, 'Charlie', 22]]
df = pd.DataFrame(data, columns=['ID', 'Name', 'Age'])
df
# Out:
#    ID     Name  Age
# 0   1    Alice   28
# 1   2      Bob   34
# 2   3  Charlie   22

# %%
# Read the first column of the CSV file into a Series
series_csv = pd.read_csv('/content/sample_data.csv', usecols=['value'])
#series_csv = pd.read_csv('/content/sample_data/california_housing_test.csv')

# Display the Series
#print(series_csv)
series_csv
# Out:
#    value
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50

# %%
# Replace with the path to your Excel file
file_path = '/content/sample_data.xls'
# Reading the Excel file
df = pd.read_excel(file_path)
# Display the DataFrame
df
# Out:
#     ชื่อ  อายุ      อาชีพ
# 0  สมชาย    30     วิศวกร
# 1  วรรณา    28  นักออกแบบ

# %%
# URL of the JSON data
json_url = 'https://covid19.ddc.moph.go.th/api/Cases/today-cases-by-provinces'

# Read JSON data from the URL into a DataFrame
df = pd.read_json(json_url)

# Display the first few rows of the DataFrame
df
# Out:
#     year  weeknum  province  new_case  total_case  new_case_excludeabroad  \
# 0   2023       45  ร้อยเอ็ด         4         488                       4
# 1   2023       45    นครปฐม         1         309                       1
# 2   2023       45     ระนอง         0          79                       0
# 3   2023       45    นครพนม         2         116                       2
# 4   2023       45     ยโสธร         1         154                       1
# ..   ...      ...       ...       ...         ...                     ...
# 74  2023       45  ศรีสะเกษ         0         264                       0
# 75  2023       45   อ่างทอง         1         245                       1
# 76  2023       45     ลำพูน         0         694                       0
# 77  2023       45  นราธิวาส         0          48                       0
# 78  2023       45      น่าน         0         236                       0
#
#     total_case_excludeabroad  new_death  total_death          update_date
# ...

# %%
# Column names that you want to assign
column_names = ['Name', 'Age', 'Occupation']

# Read the CSV file
df = pd.read_csv('/content/example_no_col.csv', header=None, names=column_names)
#df = pd.read_csv('/content/example_no_col.csv')
# header=None บอก Pandas ว่าจะไม่มี หัว column และ names = เพื่อใส่ชื่อให้ column
# Display the DataFrame
df
# Out:
#     Name  Age Occupation
# 0    Oak   28   Engineer
# 1   Jane   32     Doctor
# 2  Thane   45    Fighter
# 3    Zip   20    Teacher

# %%
data = {
   'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Ethan'],
   'Age': [25, 30, 35, 40, 45],
   'Gender': ['Female', 'Male', 'Male', 'Female', 'Male'],
   'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Gender         City
# 0    Alice   25  Female     New York
# 1      Bob   30    Male  Los Angeles
# 2  Charlie   35    Male      Chicago
# 3    Diana   40  Female      Houston
# 4    Ethan   45    Male      Phoenix

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    45
# Name: Age, dtype: int64

# %%
df.Age
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    45
# Name: Age, dtype: int64

# %%
row_data = df.iloc[4] # แถวแรก 0
row_data
# Out:
# Name        Ethan
# Age            45
# Gender       Male
# City      Phoenix
# Name: 4, dtype: object

# %%
row_data = df.iloc[0,1]
row_data
# Out:
# 25

# %%
row_data = df.loc[2] # ใช้ Row Index 2 เป็น label
row_data
# Out:
# Name      Charlie
# Age            35
# Gender       Male
# City      Chicago
# Name: 2, dtype: object

# %%
row_data = df.loc[2,'Age'] # ใช้ Row Index 2 เป็น label และ เลือก Column = City
row_data
# Out:
# 35

# %%
df.set_index('Name', inplace=True) # inplace = True เป็นการเปลี่ยน original DataFrame
df
# Out:
#          Age  Gender         City
# Name
# Alice     25  Female     New York
# Bob       30    Male  Los Angeles
# Charlie   35    Male      Chicago
# Diana     40  Female      Houston
# Ethan     45    Male      Phoenix

# %%
row_data = df.loc['Bob'] # ใช้ Row Index 'Bob' เป็น label
row_data
# Out:
# Age                30
# Gender           Male
# City      Los Angeles
# Name: Bob, dtype: object

# %%
row_data = df.loc['Ethan','City'] # ใช้ Row Index 'Ethan' เป็น label และ เลือก Column City
row_data
# Out:
# 'Phoenix'

# %%
conditional_data = df[df['Age'] > 25]
conditional_data
# Out:
#          Age  Gender         City
# Name
# Bob       30    Male  Los Angeles
# Charlie   35    Male      Chicago
# Diana     40  Female      Houston
# Ethan     45    Male      Phoenix

# %%
selected_rows = df[(df['Age'] > 30) & (df['Gender'] == 'Female')]
selected_rows
# Out:
#        Age  Gender     City
# Name
# Diana   40  Female  Houston

# %%
selected_rows = df[df['City'].isin(['New York', 'Chicago'])]
selected_rows # มีเมืองอยู่ใน New York หรือ Chicago
# Out:
#          Age  Gender      City
# Name
# Alice     25  Female  New York
# Charlie   35    Male   Chicago

# %%
selected_rows = df[~df['City'].isin(['New York', 'Chicago'])]
selected_rows
# Out:
#        Age  Gender         City
# Name
# Bob     30    Male  Los Angeles
# Diana   40  Female      Houston
# Ethan   45    Male      Phoenix

# %%
multiple_columns = df[['Age', 'City']]
multiple_columns
# Out:
#          Age         City
# Name
# Alice     25     New York
# Bob       30  Los Angeles
# Charlie   35      Chicago
# Diana     40      Houston
# Ethan     45      Phoenix

# %%
df['Age']
# Out:
# Name
# Alice      25
# Bob        30
# Charlie    35
# Diana      40
# Ethan      45
# Name: Age, dtype: int64

# %%
series["a"] #			1
# Out:
# 1

# %%
series[:2] #Slicing
# Out:
# a    1
# b    2
# dtype: int64

# %%
series[series > 2]
# Out:
# c    3
# d    4
# dtype: int64

# %%
series[-1] # 			4
# Out:
# 4

# %%
series.loc['c'] #		3
# Out:
# 3

# %%
series.iloc[3] #		4
# Out:
# 4

# %%
sliced_df = df.iloc[1:4]
sliced_df
# Out:
#          Age  Gender         City
# Name
# Bob       30    Male  Los Angeles
# Charlie   35    Male      Chicago
# Diana     40  Female      Houston

# %%
sliced_df = df.loc['Alice':'Charlie']
sliced_df
# Out:
#          Age  Gender         City
# Name
# Alice     25  Female     New York
# Bob       30    Male  Los Angeles
# Charlie   35    Male      Chicago

# %%
sliced_columns = df.iloc[:3, :2]
sliced_columns
# Out:
#          Age  Gender
# Name
# Alice     25  Female
# Bob       30    Male
# Charlie   35    Male

# %%
df.to_csv('filename.csv', index=False)

# %%
df.to_excel('filename.xlsx', index=False, engine='openpyxl')
